# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
from datetime import datetime
import statistics
# %matplotlib inline

# %%
df = pd.read_excel('forbes_100.xlsx')

# %%
df
# Out:
#     Rank                  Name Age Earnings       Category
# 0      1            Sean Combs  47   $130 M      Musicians
# 1      2       Beyoncé Knowles  35   $105 M      Musicians
# 2      3          J.K. Rowling  52    $95 M        Authors
# 3      4                 Drake  30    $94 M      Musicians
# 4      5     Cristiano Ronaldo  32    $93 M       Athletes
# 5      6            The Weeknd  27    $92 M      Musicians
# 6      7          Howard Stern  63    $90 M  Personalities
# 7      8              Coldplay   -    $88 M      Musicians
# 8      9       James Patterson  70    $87 M        Authors
# 9     10          LeBron James  32    $86 M       Athletes
# 10    11         Guns N' Roses   -    $84 M      Musicians
# 11    11         Rush Limbaugh  66    $84 M  Personalities
# 12    13         Justin Bieber  23  $83.5 M      Musicians
# 13    14          Lionel Messi  30    $80 M       Athletes
# 14    15       Dr. Phil McGraw  66    $79 M  Personalities
# ...
